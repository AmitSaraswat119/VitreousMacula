# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data=pd.read_excel("RLD.xlsx",index=False)
data.drop("Unnamed: 0",axis=1)
# Out:
#      Colour_Vision_Right_Both  Colour_Vision_Right_Green  \
# 0                           0                          1
# 1                           0                          0
# 2                           0                          1
# 3                           0                          1
# 4                           0                          0
# ..                        ...                        ...
# 295                         0                          0
# 296                         0                          0
# 297                         0                          1
# 298                         0                          1
# 299                         0                          0
#
#      Colour_Vision_Right_Red  Headache  Near Reading Problem  \
# 0                          0         0                     1
# 1                          1         1                     1
# 2                          0         1                     1
# ...

# %%
data
# Out:
#      Unnamed: 0  Colour_Vision_Right_Both  Colour_Vision_Right_Green  \
# 0             0                         0                          1
# 1             1                         0                          0
# 2             2                         0                          1
# 3             3                         0                          1
# 4             4                         0                          0
# ..          ...                       ...                        ...
# 295         295                         0                          0
# 296         296                         0                          0
# 297         297                         0                          1
# 298         298                         0                          1
# 299         299                         0                          0
#
#      Colour_Vision_Right_Red  Headache  Near Reading Problem  \
# 0                          0         0                     1
# ...

# %%
x = data.Spokes_Right
y = data.Right_Eye_Prescription_Axis

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
model_axis_r = Sequential()
model_axis_r.add(Dense(8, input_dim=1, kernel_initializer='normal', activation='relu'))
model_axis_r.add(Dense(2670, activation='relu'))
model_axis_r.add(Dense(1, activation='linear'))
model_axis_r.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 8)                 16
# _________________________________________________________________
# dense_4 (Dense)              (None, 2670)              24030
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2671
# ...
# Total params: 26,717
# Trainable params: 26,717
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_axis_r.compile(loss='mse', optimizer='adam', metrics=['accuracy','mse','mae'])

# %%
model_axis_r.fit(X_train, y_train,epochs=900,batch_size=10)
# Out:
# Epoch 1/900
# 24/24 [==============================] - 0s 855us/step - loss: 5994.3784 - accuracy: 0.4542 - mse: 5994.3784 - mae: 45.2156
# Epoch 2/900
# 24/24 [==============================] - 0s 895us/step - loss: 5680.2520 - accuracy: 0.0000e+00 - mse: 5680.2520 - mae: 44.6880
# Epoch 3/900
# 24/24 [==============================] - 0s 899us/step - loss: 4897.9287 - accuracy: 0.0000e+00 - mse: 4897.9287 - mae: 43.2882
# Epoch 4/900
# 24/24 [==============================] - 0s 935us/step - loss: 3365.0154 - accuracy: 0.0000e+00 - mse: 3365.0154 - mae: 39.2739
# Epoch 5/900
# 24/24 [==============================] - 0s 943us/step - loss: 1778.3433 - accuracy: 0.0000e+00 - mse: 1778.3433 - mae: 33.3060
# Epoch 6/900
# 24/24 [==============================] - 0s 976us/step - loss: 850.3475 - accuracy: 0.0000e+00 - mse: 850.3475 - mae: 26.0541
# Epoch 7/900
# 24/24 [==============================] - 0s 895us/step - loss: 575.9542 - accuracy: 0.0000e+00 - mse: 575.9542 - mae: 20.9304
# ...

# %%
x_new = np.arange(7).reshape((-1, 1))
x_new
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
pred = model_axis_r.predict(x_new)

# %%
pred
# Out:
# array([[ -0.87936175],
#        [ 27.281803  ],
#        [ 58.201862  ],
#        [ 89.121925  ],
#        [120.04198   ],
#        [146.08601   ],
#        [170.59416   ]], dtype=float32)

# %%
from tensorflow.keras.models import save_model
model_axis_r.save("model_axis_r.h5")
